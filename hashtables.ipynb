# %%
from typing import Optional, List
class LinkedListNode:
    def __init__(self, key=None, value=0, next=None, prev=None):
        self.key = key
        self.value = value
        self.next = next
        self.prev = prev
    
    def __repr__(self):
        return str(self.value)

class LinkedList:
    def __init__(self, iterable: List[int] = []):
        self.head = None
        self.tail = None
        self.size = 0

        if iterable:
            for value in iterable:
                self.append(LinkedListNode(value))
                self.size += 1
        
    def __bool__(self):
        return self.size != 0

    def __repr__(self):
        nodes = []
        current_node = self.head
        while current_node:
            nodes.append(str(current_node.value))
            current_node = current_node.next
        return ' <-> '.join(nodes)

    def append(self, new_node: LinkedListNode|int):
        if type(new_node) is int:
            new_node = LinkedListNode(new_node)
            
        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        self.size += 1

    def remove(self, node: LinkedListNode):
        """
        Removes a given node from the linked list
        """

        if not node:
            return 
        
        if node == self.head:
            self.head = self.head.next
            self.head.prev = None
        elif node == self.tail:
            self.tail = self.tail.prev
            self.tail.next = None
        else:
            node.prev.next = node.next
            node.next.prev = node.prev
    
        self.size -= 1
        return
    

    def find_key(self, key: int) -> Optional[LinkedListNode]:
        """
        Returns a pointer to the first node with the given value
        """

        current_node = self.head
        while current_node:
            if current_node.key == key:
                return current_node
            current_node = current_node.next

        return None

# %%
class ClosedAddressingHashTable:

    """
    Closed Addressing Hash Table implementation from scratch.
    Closed addressing is a technique for resolving collisions in hash tables that involves
    using a fixed-size array to store the hash table entries and chaining to resolve collisions.

    Chaining:
        - Each slot in the hash table contains some data structure of items that have the same hash value.
            - Today I will use a linked list. Dynamic arrays, or BSTs can also be used.
        - When an item is inserted into the hash table, it is added to the end of the linked list along with the key. This way we can look for it properly later.
            
    Dynamic resizing:
        - When the load factor exceeds the max load factor, the hash table is resized by doubling its capacity.


    """
    def __init__(self, capacity: int = 1999, load_factor: float = 0.75):
        self.size = 0
        self.capacity = capacity
        self.table = [LinkedList() for _ in range(capacity)]
        self.current_load_factor = 0
        self.max_load_factor = load_factor
   
    def __contains__(self, key) -> bool:
        table_idx = hash(key) % self.capacity
        ll = self.table[table_idx]
        result = ll.find_key(key)
        return result is not None
    
    def __len__(self):
        return self.size
    
    def __getitem__(self, key):
        return self.get(key)
    
    def __setitem__(self, key, value):
        self.set(key, value)
        
    def __delitem__(self, key):
        self.remove(key)

    def __repr__(self):
        result = ''
        for ll in self.table:
            if ll:
                result += f"{ll}\n"
        return result
    
    """Helper methods"""

    def _check_load_factor(self):
        if self.current_load_factor >= self.max_load_factor:
            self._resize(self.capacity * 2)
        self.current_load_factor = self.size/self.capacity
        return self.current_load_factor
        
    
    def _resize(self, new_capacity: int):
        number_of_linkedlists_to_add = new_capacity - self.capacity
        self.capacity = new_capacity
        self.table += [LinkedList() for _ in range(number_of_linkedlists_to_add)]

    """Functionality"""

    def set(self, key, value):
        # Check if the key is in the hashtable
        table_idx = hash(key) % self.capacity
        ll = self.table[table_idx]
        node = ll.find_key(key)
        # If the key is not found, append new node
        if node is None:
            self._check_load_factor()
            node = LinkedListNode(key, value)
            ll.append(node)
            self.size += 1
        # If it is, update the value
        else:
            node.value = value

    def remove(self, key):
        table_idx = hash(key) % self.capacity
        ll = self.table[table_idx]
        node = ll.find_key(key)
        if node is None:
            raise KeyError(f"{key} not found")
        else:
            ll.remove(node)
            self.size -= 1
            return True
        
    def get(self, key):
        table_idx = hash(key) % self.capacity
        ll = self.table[table_idx]
        node = ll.find_key(key)

        if node is None:
            raise KeyError(f"{key} not found")
        else:
            return node.value

d = ClosedAddressingHashTable(4)
d[1] = 1
d[2] = 2
d[33] = 33
d[2] = 2.5
d[3] = 3
d[4] = 4
print(d)
print(1 in d)
print(32 in d)
print(d.size, d.current_load_factor, d.capacity)
# Out:
# 4
# 1 <-> 33
# 2.5
# 3
#
# True
# False
# 5 0.5 8

# %%
class OpenAddressingHashTable:
    """
    Open Addressing Hash Table implementation from scratch.
    Open addressing also known as probing is a technique for resolving collisions in hash tables.
    There are two main types of open addressing: linear probing and quadratic probing.
    Probing is used to resolve collisions by finding the next available slot in the hash table, and slotting in the element there.

    Linear probing:
        h(key) = (hash(key) + i) % capacity
        i = 0, 1, 2, ...

    Quadratic probing:
        h(key) = (hash(key) + i**2) % capacity
        i = 0, 1, 2, ...
    """

    def __init__(self, capacity: int = 1999, probe_type: str = 'linear', load_factor: float = 0.75):
        self.size = 0
        self.capacity = capacity 
        self.table = [(None, None)] * capacity
        self.current_load_factor = 0
        self.max_load_factor = load_factor

        probe_types = {
            'linear': self._linear_probe,
            'quadratic': self._quadratic_probe,
        }
        
        if probe_type not in probe_types:
            raise ValueError(f"Invalid probe type: {probe_type}. Valid probe types are: {list(probe_types.keys())}")
        else:
            self.probe_function = probe_types[probe_type]

   
    def __contains__(self, key) -> bool:
        result = self.get(key)
        return result is not None
    
    def __len__(self):
        return self.size
    
    def __getitem__(self, key):
        return self.get(key)
    
    def __setitem__(self, key, value):
        self.set(key, value)

    def __delitem__(self, key):
        self.remove(key)

    def __repr__(self):
        result = ''
        for i, item in enumerate(self.table):
            if item[1] is not None:
                result += f"{i}: {item}\n"
        return result

    """Probing methods"""

    def _linear_probe(self, idx, i):
        return (idx + i) % self.capacity
        
    def _quadratic_probe(self, idx, i):
        return (idx + i**2) % self.capacity
    
    """Helper methods"""

    def _check_load_factor(self):
        if self.current_load_factor >= self.max_load_factor:
            self._resize(self.capacity * 2)
        self.current_load_factor = self.size/self.capacity
        return self.current_load_factor 
    
    def _resize(self, new_capacity: int):
        number_of_spaces_to_add = new_capacity - self.capacity
        self.capacity = new_capacity
        self.table += [(None, None)] * number_of_spaces_to_add

    """Functionality"""

    def set(self, key, value):
        self._check_load_factor()
        table_idx = hash(key) % self.capacity
        k, v = self.table[table_idx]
        n_collisions = 0
        while k is not None and k != key and k != -1:
            table_idx = self.probe_function(table_idx, n_collisions)
            k, v = self.table[table_idx]
            n_collisions += 1
        if k is None or k == -1:
            self.size += 1
        self.table[table_idx] = (key, value)

    def remove(self, key) -> bool:
        table_idx = hash(key) % self.capacity
        k, v = self.table[table_idx]
        n_collisions = 0
        while k is not None:
            if k == key:
                self.table[table_idx] = (-1, None)
                self.size -= 1
                return True
            table_idx = self.probe_function(table_idx, n_collisions)
            k, v = self.table[table_idx]
            n_collisions += 1
        
        # If not found
        return False
        
    def get(self, key) -> Optional[int]:
        table_idx = hash(key) % self.capacity
        n_collisions = 0
        k, v = self.table[table_idx]
        while k is not None and n_collisions < self.capacity:
            if k == key:
                return v
            
            table_idx = self.probe_function(table_idx, n_collisions)
            k, v = self.table[table_idx]
            n_collisions += 1
        return None


d = OpenAddressingHashTable(32, 'quadratic')
d[1] = 1
d[2] = 2
d[33] = 33
d[2] = 2.5
d[3] = 3
d[4] = 4
d[9] = 9
print(d)
print(1 in d)
print(32 in d)
print(d.size, d.current_load_factor, d.capacity)
# Out:
# 1: (1, 1)
# 2: (2, 2.5)
# 3: (3, 3)
# 4: (4, 4)
# 6: (33, 33)
# 9: (9, 9)
#
# True
# False
# 6 0.15625 32

# %% [markdown]
# ## Tests
#
# ### Methods
#     - We'll test these hashtables on 3 different types of data: integers, floats, and strings
#     - We'll measure the memory footprint and CPU time.
#     - We will store and then retrieve 10000 pieces of data for each one.

# %%
import tracemalloc
import time
import random
import string

# %%
def profile_hashtable(table, items: List[List]):
    # Generate the data
    tracemalloc.start()
    start = time.time()
    d = {}
    for key, value in items:
        table[key] = value
        d[key] = value
    for key, value in items:
        assert table[key] == d[key], f"Error at key {key}: Value {table[key]} is not equal to {d[key]}"
    for key, value in items:
        try:
            del table[key]
        except:
            print(f"Error at key {key}")

    end = time.time()
    _, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return peak, end - start

# %%
items_int = [[random.randint(0, 1000), random.randint(0, 1000)] for _ in range(10000)]
items_float = [[random.uniform(0, 1000), random.uniform(0, 1000)] for _ in range(10000)]
items_string = [[random.choice(string.ascii_letters), random.choice(string.ascii_letters)] for _ in range(10000)]

# %%
# Test on integers
separate_chaining = ClosedAddressingHashTable()
open_addressing_linear = OpenAddressingHashTable()
open_addressing_quadratic = OpenAddressingHashTable(probe_type='quadratic')


peak_sc, time_sc = profile_hashtable(separate_chaining, items_int)
peak_oal, time_oal = profile_hashtable(open_addressing_linear, items_int)    
peak_oaq, time_oaq = profile_hashtable(open_addressing_quadratic, items_int)    
print(f"Separate Chaining: {peak_sc} bytes, {time_sc} seconds")    
print(f"Open Addressing Linear: {peak_oal} bytes, {time_oal} seconds")    
print(f"Open Addressing Quadratic: {peak_oaq} bytes, {time_oaq} seconds")
# Out:
# Error at key 594
# Error at key 951
# Error at key 333
# Error at key 49
# Error at key 882
# Error at key 413
# Error at key 489
# Error at key 884
# Error at key 826
# Error at key 600
# Error at key 865
# Error at key 325
# Error at key 2
# Error at key 899
# Error at key 53
# Error at key 166
# Error at key 359
# Error at key 766
# Error at key 522
# Error at key 885
# Error at key 538
# Error at key 837
# Error at key 677
# Error at key 149
# Error at key 523
# Error at key 100
# Error at key 279
# Error at key 856
# Error at key 34
# Error at key 83
# Error at key 501
# Error at key 197
# Error at key 682
# Error at key 959
# Error at key 965
# Error at key 538
# Error at key 451
# Error at key 371
# Error at key 147
# Error at key 860
# Error at key 403
# Error at key 898
# Error at key 440
# Error at key 741
# Error at key 860
# Error at key 333
# Error at key 931
# Error at key 192
# Error at key 451
# Error at key 991
# Error at key 642
# Error at key 978
# Error at key 998
# Error at key 265
# Error at key 838
# Error at key 561
# Error at key 281
# Error at key 710
# Error at key 68
# Error at key 133
# Error at key 158
# Error at key 157
# Error at key 339
# Error at key 768
# Error at key 332
# Error at key 853
# Error at key 106
# Error at key 286
# Error at key 152
# Error at key 579
# Error at key 554
# Error at key 371
# Error at key 936
# Error at key 127
# Error at key 376
# Error at key 140
# Error at key 311
# Error at key 110
# Error at key 537
# Error at key 843
# Error at key 393
# Error at key 532
# Error at key 264
# Error at key 626
# Error at key 866
# Error at key 977
# Error at key 597
# Error at key 144
# Error at key 832
# Error at key 417
# Error at key 767
# Error at key 297
# Error at key 292
# Error at key 180
# Error at key 871
# Error at key 644
# Error at key 812
# Error at key 993
# Error at key 352
# Error at key 427
# Error at key 486
# Error at key 854
# Error at key 275
# Error at key 892
# Error at key 458
# Error at key 370
# Error at key 748
# Error at key 788
# Error at key 347
# Error at key 214
# Error at key 589
# Error at key 197
# Error at key 313
# Error at key 242
# Error at key 928
# Error at key 31
# Error at key 950
# Error at key 992
# Error at key 247
# Error at key 188
# Error at key 841
# Error at key 384
# Error at key 837
# Error at key 19
# Error at key 539
# Error at key 945
# Error at key 440
# Error at key 916
# Error at key 226
# Error at key 35
# Error at key 894
# Error at key 270
# Error at key 223
# Error at key 733
# Error at key 985
# Error at key 904
# Error at key 474
# Error at key 900
# Error at key 907
# Error at key 277
# Error at key 46
# Error at key 686
# Error at key 390
# Error at key 101
# Error at key 381
# Error at key 801
# Error at key 67
# Error at key 852
# Error at key 534
# Error at key 675
# Error at key 763
# Error at key 413
# Error at key 763
# Error at key 342
# Error at key 858
# Error at key 46
# Error at key 347
# Error at key 959
# Error at key 728
# Error at key 867
# Error at key 791
# Error at key 963
# Error at key 79
# Error at key 996
# Error at key 142
# Error at key 899
# Error at key 955
# Error at key 917
# Error at key 651
# Error at key 37
# Error at key 614
# Error at key 176
# Error at key 995
# Error at key 931
# Error at key 650
# Error at key 369
# Error at key 705
# Error at key 299
# Error at key 649
# Error at key 49
# Error at key 930
# Error at key 145
# Error at key 210
# Error at key 17
# Error at key 603
# Error at key 329
# Error at key 137
# Error at key 835
# Error at key 332
# Error at key 14
# Error at key 893
# Error at key 763
# Error at key 991
# Error at key 7
# Error at key 348
# Error at key 103
# Error at key 379
# Error at key 494
# Error at key 227
# Error at key 177
# Error at key 444
# Error at key 811
# Error at key 225
# Error at key 731
# Error at key 118
# Error at key 167
# Error at key 79
# Error at key 576
# Error at key 670
# Error at key 528
# Error at key 33
# Error at key 545
# Error at key 869
# Error at key 586
# Error at key 723
# Error at key 169
# Error at key 48
# Error at key 169
# Error at key 542
# Error at key 772
# Error at key 34
# Error at key 454
# Error at key 506
# Error at key 558
# Error at key 840
# Error at key 96
# Error at key 664
# Error at key 590
# Error at key 861
# Error at key 925
# Error at key 215
# Error at key 648
# Error at key 556
# Error at key 949
# Error at key 618
# Error at key 420
# Error at key 395
# Error at key 873
# Error at key 650
# Error at key 615
# Error at key 803
# Error at key 589
# Error at key 853
# Error at key 170
# Error at key 121
# Error at key 727
# Error at key 861
# Error at key 694
# Error at key 768
# Error at key 742
# Error at key 482
# Error at key 74
# Error at key 643
# Error at key 647
# Error at key 902
# Error at key 879
# Error at key 835
# Error at key 905
# Error at key 419
# Error at key 5
# Error at key 965
# Error at key 149
# Error at key 33
# Error at key 203
# Error at key 570
# Error at key 101
# Error at key 708
# Error at key 741
# Error at key 520
# Error at key 197
# Error at key 670
# Error at key 39
# Error at key 821
# Error at key 540
# Error at key 548
# Error at key 171
# Error at key 651
# Error at key 576
# Error at key 92
# Error at key 516
# Error at key 43
# Error at key 871
# Error at key 0
# Error at key 81
# Error at key 55
# Error at key 472
# Error at key 621
# Error at key 542
# Error at key 807
# Error at key 638
# Error at key 283
# Error at key 520
# Error at key 569
# Error at key 270
# Error at key 271
# Error at key 156
# Error at key 350
# Error at key 135
# Error at key 97
# Error at key 166
# Error at key 531
# Error at key 148
# Error at key 433
# Error at key 765
# Error at key 649
# Error at key 181
# Error at key 556
# Error at key 362
# Error at key 0
# Error at key 657
# Error at key 302
# Error at key 473
# Error at key 491
# Error at key 32
# Error at key 514
# Error at key 381
# Error at key 675
# Error at key 110
# Error at key 253
# Error at key 874
# Error at key 239
# Error at key 86
# Error at key 459
# Error at key 779
# Error at key 517
# Error at key 269
# Error at key 708
# Error at key 492
# Error at key 656
# Error at key 584
# Error at key 312
# Error at key 150
# Error at key 859
# Error at key 739
# Error at key 365
# Error at key 286
# Error at key 241
# Error at key 11
# Error at key 842
# Error at key 58
# Error at key 286
# Error at key 882
# Error at key 360
# Error at key 185
# Error at key 282
# Error at key 215
# Error at key 101
# Error at key 853
# Error at key 301
# Error at key 673
# Error at key 137
# Error at key 611
# Error at key 228
# Error at key 36
# Error at key 363
# Error at key 92
# Error at key 250
# Error at key 839
# Error at key 157
# Error at key 182
# Error at key 45
# Error at key 622
# Error at key 801
# Error at key 190
# Error at key 1000
# Error at key 633
# Error at key 716
# Error at key 771
# Error at key 928
# Error at key 919
# Error at key 171
# Error at key 37
# Error at key 410
# Error at key 520
# Error at key 624
# Error at key 205
# Error at key 873
# Error at key 833
# Error at key 581
# Error at key 650
# Error at key 904
# Error at key 343
# Error at key 856
# Error at key 653
# Error at key 747
# Error at key 39
# Error at key 821
# Error at key 748
# Error at key 105
# Error at key 343
# Error at key 655
# Error at key 125
# Error at key 985
# Error at key 688
# Error at key 593
# Error at key 388
# Error at key 406
# Error at key 81
# Error at key 243
# Error at key 89
# Error at key 410
# Error at key 461
# Error at key 767
# Error at key 228
# Error at key 614
# Error at key 78
# Error at key 970
# Error at key 963
# Error at key 394
# Error at key 193
# Error at key 10
# Error at key 121
# Error at key 496
# Error at key 32
# Error at key 334
# Error at key 124
# Error at key 845
# Error at key 896
# Error at key 106
# Error at key 9
# Error at key 708
# Error at key 13
# Error at key 263
# Error at key 764
# Error at key 170
# Error at key 69
# Error at key 422
# Error at key 750
# Error at key 892
# Error at key 541
# Error at key 933
# Error at key 852
# Error at key 439
# Error at key 211
# Error at key 968
# Error at key 425
# Error at key 706
# Error at key 914
# Error at key 822
# Error at key 918
# Error at key 366
# Error at key 482
# Error at key 489
# Error at key 959
# Error at key 421
# Error at key 700
# Error at key 974
# Error at key 915
# Error at key 235
# Error at key 7
# Error at key 852
# Error at key 587
# Error at key 855
# Error at key 39
# Error at key 686
# Error at key 914
# Error at key 267
# Error at key 826
# Error at key 780
# Error at key 465
# Error at key 517
# Error at key 42
# Error at key 395
# Error at key 541
# Error at key 758
# Error at key 155
# Error at key 538
# Error at key 705
# Error at key 107
# Error at key 380
# Error at key 373
# Error at key 499
# Error at key 649
# Error at key 204
# Error at key 627
# Error at key 501
# Error at key 508
# Error at key 684
# Error at key 1000
# Error at key 973
# Error at key 262
# Error at key 731
# Error at key 155
# Error at key 37
# Error at key 805
# Error at key 419
# Error at key 756
# Error at key 312
# Error at key 501
# Error at key 191
# Error at key 164
# Error at key 399
# Error at key 908
# Error at key 755
# Error at key 789
# Error at key 256
# Error at key 171
# Error at key 970
# Error at key 527
# Error at key 16
# Error at key 234
# Error at key 601
# Error at key 123
# Error at key 902
# Error at key 226
# Error at key 783
# Error at key 596
# Error at key 657
# Error at key 24
# Error at key 638
# Error at key 440
# Error at key 243
# Error at key 578
# Error at key 642
# Error at key 128
# Error at key 778
# Error at key 118
# Error at key 68
# Error at key 128
# Error at key 909
# Error at key 439
# Error at key 263
# Error at key 30
# Error at key 204
# Error at key 409
# Error at key 263
# Error at key 152
# Error at key 219
# Error at key 824
# Error at key 620
# Error at key 984
# Error at key 539
# Error at key 790
# Error at key 658
# Error at key 738
# Error at key 118
# Error at key 410
# Error at key 263
# Error at key 688
# Error at key 275
# Error at key 606
# Error at key 892
# Error at key 721
# Error at key 260
# Error at key 268
# Error at key 865
# Error at key 663
# Error at key 849
# Error at key 276
# Error at key 34
# Error at key 949
# Error at key 490
# Error at key 187
# Error at key 261
# Error at key 651
# Error at key 72
# Error at key 319
# Error at key 668
# Error at key 94
# Error at key 144
# Error at key 220
# Error at key 588
# Error at key 695
# Error at key 64
# Error at key 560
# Error at key 378
# Error at key 994
# Error at key 420
# Error at key 602
# Error at key 527
# Error at key 173
# Error at key 777
# Error at key 900
# Error at key 978
# Error at key 201
# Error at key 185
# Error at key 947
# Error at key 154
# Error at key 870
# Error at key 108
# Error at key 449
# Error at key 961
# Error at key 761
# Error at key 690
# Error at key 661
# Error at key 647
# Error at key 686
# Error at key 252
# Error at key 849
# Error at key 557
# Error at key 45
# Error at key 265
# Error at key 502
# Error at key 504
# Error at key 856
# Error at key 529
# Error at key 122
# Error at key 309
# Error at key 344
# Error at key 997
# Error at key 122
# Error at key 7
# Error at key 385
# Error at key 194
# Error at key 834
# Error at key 510
# Error at key 623
# Error at key 24
# Error at key 590
# Error at key 331
# Error at key 524
# Error at key 950
# Error at key 175
# Error at key 68
# Error at key 407
# Error at key 635
# Error at key 980
# Error at key 841
# Error at key 615
# Error at key 458
# Error at key 834
# Error at key 867
# Error at key 984
# Error at key 25
# Error at key 697
# Error at key 401
# Error at key 780
# Error at key 976
# Error at key 39
# Error at key 315
# Error at key 702
# Error at key 161
# Error at key 961
# Error at key 569
# Error at key 497
# Error at key 931
# Error at key 681
# Error at key 608
# Error at key 194
# Error at key 146
# Error at key 534
# Error at key 426
# Error at key 525
# Error at key 758
# Error at key 75
# Error at key 440
# Error at key 380
# Error at key 704
# Error at key 467
# Error at key 606
# Error at key 853
# Error at key 400
# Error at key 667
# Error at key 746
# Error at key 547
# Error at key 596
# Error at key 463
# Error at key 839
# Error at key 86
# Error at key 452
# Error at key 328
# Error at key 573
# Error at key 741
# Error at key 111
# Error at key 195
# Error at key 924
# Error at key 619
# Error at key 803
# Error at key 885
# Error at key 669
# Error at key 313
# Error at key 693
# Error at key 645
# Error at key 357
# Error at key 589
# Error at key 664
# Error at key 240
# Error at key 589
# Error at key 312
# Error at key 430
# Error at key 819
# Error at key 139
# Error at key 56
# Error at key 977
# Error at key 451
# Error at key 540
# Error at key 530
# Error at key 665
# Error at key 634
# Error at key 474
# Error at key 329
# Error at key 801
# Error at key 829
# Error at key 599
# Error at key 512
# Error at key 123
# Error at key 153
# Error at key 308
# Error at key 252
# Error at key 727
# Error at key 139
# Error at key 489
# Error at key 693
# Error at key 490
# Error at key 249
# Error at key 683
# Error at key 196
# Error at key 462
# Error at key 569
# Error at key 897
# Error at key 269
# Error at key 397
# Error at key 646
# Error at key 222
# Error at key 564
# Error at key 312
# Error at key 841
# Error at key 134
# Error at key 996
# Error at key 673
# Error at key 11
# Error at key 14
# Error at key 517
# Error at key 641
# Error at key 160
# Error at key 853
# Error at key 629
# Error at key 752
# Error at key 130
# Error at key 154
# Error at key 937
# Error at key 577
# Error at key 469
# Error at key 455
# Error at key 507
# Error at key 241
# Error at key 710
# Error at key 149
# Error at key 399
# Error at key 878
# Error at key 457
# Error at key 116
# Error at key 175
# Error at key 180
# Error at key 765
# Error at key 478
# Error at key 627
# Error at key 499
# Error at key 555
# Error at key 366
# Error at key 56
# Error at key 973
# Error at key 718
# Error at key 266
# Error at key 143
# Error at key 498
# Error at key 297
# Error at key 49
# Error at key 411
# Error at key 28
# Error at key 608
# Error at key 892
# Error at key 103
# Error at key 835
# Error at key 851
# Error at key 38
# Error at key 695
# Error at key 884
# Error at key 233
# Error at key 79
# Error at key 954
# Error at key 74
# Error at key 440
# Error at key 167
# Error at key 489
# Error at key 974
# Error at key 289
# Error at key 93
# Error at key 923
# Error at key 528
# Error at key 46
# Error at key 843
# Error at key 417
# Error at key 782
# Error at key 61
# Error at key 994
# Error at key 831
# Error at key 889
# Error at key 986
# Error at key 614
# Error at key 171
# Error at key 165
# Error at key 651
# Error at key 702
# Error at key 991
# Error at key 760
# Error at key 200
# Error at key 235
# Error at key 218
# Error at key 230
# Error at key 43
# Error at key 277
# Error at key 721
# Error at key 440
# Error at key 963
# Error at key 696
# Error at key 847
# Error at key 174
# Error at key 709
# Error at key 729
# Error at key 454
# Error at key 582
# Error at key 932
# Error at key 49
# Error at key 248
# Error at key 746
# Error at key 668
# Error at key 449
# Error at key 757
# Error at key 981
# Error at key 117
# Error at key 25
# Error at key 171
# Error at key 135
# Error at key 25
# Error at key 153
# Error at key 821
# Error at key 354
# Error at key 764
# Error at key 249
# Error at key 458
# Error at key 646
# Error at key 58
# Error at key 544
# Error at key 190
# Error at key 759
# Error at key 899
# Error at key 176
# Error at key 968
# Error at key 775
# Error at key 152
# Error at key 30
# Error at key 920
# Error at key 746
# Error at key 541
# Error at key 767
# Error at key 700
# Error at key 826
# Error at key 992
# Error at key 153
# Error at key 991
# Error at key 513
# Error at key 754
# Error at key 256
# Error at key 192
# Error at key 139
# Error at key 80
# Error at key 456
# Error at key 436
# Error at key 389
# Error at key 545
# Error at key 324
# Error at key 454
# Error at key 246
# Error at key 560
# Error at key 562
# Error at key 857
# Error at key 557
# Error at key 822
# Error at key 411
# Error at key 218
# Error at key 131
# Error at key 954
# Error at key 182
# Error at key 720
# Error at key 661
# Error at key 881
# Error at key 294
# Error at key 799
# Error at key 775
# Error at key 449
# Error at key 717
# Error at key 246
# Error at key 447
# Error at key 785
# Error at key 150
# Error at key 714
# Error at key 176
# Error at key 299
# Error at key 652
# Error at key 723
# Error at key 567
# Error at key 691
# Error at key 173
# Error at key 252
# Error at key 603
# Error at key 362
# Error at key 244
# Error at key 600
# Error at key 334
# Error at key 549
# Error at key 723
# Error at key 625
# Error at key 396
# Error at key 185
# Error at key 144
# Error at key 963
# Error at key 53
# Error at key 84
# Error at key 860
# Error at key 789
# Error at key 576
# Error at key 747
# Error at key 962
# Error at key 841
# Error at key 340
# Error at key 130
# Error at key 251
# Error at key 207
# Error at key 909
# Error at key 664
# Error at key 194
# Error at key 823
# Error at key 777
# Error at key 508
# Error at key 97
# Error at key 544
# Error at key 461
# Error at key 374
# Error at key 184
# Error at key 951
# Error at key 826
# Error at key 810
# Error at key 519
# Error at key 419
# Error at key 278
# Error at key 159
# Error at key 922
# Error at key 661
# Error at key 415
# Error at key 116
# Error at key 718
# Error at key 313
# Error at key 158
# Error at key 115
# Error at key 946
# Error at key 766
# Error at key 9
# Error at key 368
# Error at key 312
# Error at key 282
# Error at key 372
# Error at key 281
# Error at key 619
# Error at key 420
# Error at key 747
# Error at key 45
# Error at key 819
# Error at key 310
# Error at key 339
# Error at key 682
# Error at key 315
# Error at key 87
# Error at key 275
# Error at key 614
# Error at key 777
# Error at key 19
# Error at key 899
# Error at key 567
# Error at key 317
# Error at key 985
# Error at key 610
# Error at key 804
# Error at key 231
# Error at key 793
# Error at key 945
# Error at key 144
# Error at key 963
# Error at key 576
# Error at key 746
# Error at key 791
# Error at key 244
# Error at key 370
# Error at key 396
# Error at key 833
# Error at key 126
# Error at key 165
# Error at key 766
# Error at key 970
# Error at key 403
# Error at key 74
# Error at key 273
# Error at key 127
# Error at key 277
# Error at key 254
# Error at key 455
# Error at key 964
# Error at key 794
# Error at key 817
# Error at key 809
# Error at key 268
# Error at key 508
# Error at key 612
# Error at key 471
# Error at key 934
# Error at key 923
# Error at key 226
# Error at key 802
# Error at key 440
# Error at key 230
# Error at key 845
# Error at key 897
# Error at key 24
# Error at key 642
# Error at key 459
# Error at key 970
# Error at key 934
# Error at key 713
# Error at key 164
# Error at key 596
# Error at key 920
# Error at key 435
# Error at key 966
# Error at key 647
# Error at key 191
# Error at key 294
# Error at key 151
# Error at key 979
# Error at key 479
# Error at key 406
# Error at key 965
# Error at key 783
# Error at key 995
# Error at key 537
# Error at key 277
# Error at key 520
# Error at key 825
# Error at key 157
# Error at key 803
# Error at key 169
# Error at key 335
# Error at key 916
# Error at key 686
# Error at key 160
# Error at key 907
# Error at key 768
# Error at key 64
# Error at key 294
# Error at key 664
# Error at key 572
# Error at key 332
# Error at key 830
# Error at key 737
# Error at key 822
# Error at key 733
# Error at key 348
# Error at key 964
# Error at key 235
# Error at key 797
# Error at key 342
# Error at key 560
# Error at key 794
# Error at key 562
# Error at key 961
# Error at key 290
# Error at key 13
# Error at key 606
# Error at key 8
# Error at key 476
# Error at key 535
# Error at key 159
# Error at key 230
# Error at key 328
# Error at key 912
# Error at key 840
# Error at key 869
# Error at key 294
# Error at key 823
# Error at key 416
# Error at key 187
# Error at key 841
# Error at key 175
# Error at key 350
# Error at key 221
# Error at key 691
# Error at key 876
# Error at key 637
# Error at key 568
# Error at key 987
# Error at key 453
# Error at key 167
# Error at key 111
# Error at key 492
# Error at key 148
# Error at key 166
# Error at key 937
# Error at key 580
# Error at key 598
# Error at key 835
# Error at key 448
# Error at key 355
# Error at key 350
# Error at key 164
# Error at key 775
# Error at key 642
# Error at key 841
# Error at key 243
# Error at key 328
# Error at key 631
# Error at key 172
# Error at key 561
# Error at key 1000
# Error at key 6
# Error at key 308
# Error at key 293
# Error at key 473
# Error at key 785
# Error at key 663
# Error at key 973
# Error at key 234
# Error at key 922
# Error at key 586
# Error at key 996
# Error at key 528
# Error at key 449
# Error at key 861
# Error at key 750
# Error at key 413
# Error at key 140
# Error at key 667
# Error at key 266
# Error at key 718
# Error at key 650
# Error at key 764
# Error at key 697
# Error at key 969
# Error at key 177
# Error at key 778
# Error at key 397
# Error at key 250
# Error at key 339
# Error at key 205
# Error at key 957
# Error at key 472
# Error at key 647
# Error at key 579
# Error at key 882
# Error at key 949
# Error at key 543
# Error at key 208
# Error at key 131
# Error at key 277
# Error at key 53
# Error at key 449
# Error at key 599
# Error at key 501
# Error at key 585
# Error at key 940
# Error at key 814
# Error at key 957
# Error at key 314
# Error at key 294
# Error at key 14
# Error at key 823
# Error at key 517
# Error at key 225
# Error at key 244
# Error at key 977
# Error at key 300
# Error at key 889
# Error at key 508
# Error at key 298
# Error at key 232
# Error at key 275
# Error at key 599
# Error at key 864
# Error at key 939
# Error at key 704
# Error at key 184
# Error at key 331
# Error at key 481
# Error at key 565
# Error at key 291
# Error at key 568
# Error at key 662
# Error at key 407
# Error at key 296
# Error at key 403
# Error at key 476
# Error at key 131
# Error at key 198
# Error at key 454
# Error at key 41
# Error at key 278
# Error at key 417
# Error at key 975
# Error at key 952
# Error at key 15
# Error at key 930
# Error at key 846
# Error at key 119
# Error at key 433
# Error at key 872
# Error at key 534
# Error at key 625
# Error at key 465
# Error at key 694
# Error at key 248
# Error at key 120
# Error at key 447
# Error at key 598
# Error at key 490
# Error at key 341
# Error at key 155
# Error at key 224
# Error at key 125
# Error at key 420
# Error at key 890
# Error at key 828
# Error at key 844
# Error at key 181
# Error at key 438
# Error at key 951
# Error at key 298
# Error at key 210
# Error at key 198
# Error at key 28
# Error at key 692
# Error at key 126
# Error at key 549
# Error at key 797
# Error at key 97
# Error at key 699
# Error at key 180
# Error at key 220
# Error at key 52
# Error at key 977
# Error at key 500
# Error at key 828
# Error at key 157
# Error at key 237
# Error at key 340
# Error at key 790
# Error at key 608
# Error at key 664
# Error at key 198
# Error at key 641
# Error at key 539
# Error at key 114
# Error at key 875
# Error at key 322
# Error at key 610
# Error at key 819
# Error at key 987
# Error at key 552
# Error at key 608
# Error at key 466
# Error at key 162
# Error at key 147
# Error at key 755
# Error at key 242
# Error at key 213
# Error at key 853
# Error at key 362
# Error at key 550
# Error at key 536
# Error at key 789
# Error at key 133
# Error at key 228
# Error at key 290
# Error at key 377
# Error at key 117
# Error at key 871
# Error at key 420
# Error at key 103
# Error at key 598
# Error at key 842
# Error at key 872
# Error at key 29
# Error at key 554
# Error at key 255
# Error at key 451
# Error at key 636
# Error at key 484
# Error at key 479
# Error at key 890
# Error at key 786
# Error at key 766
# Error at key 557
# Error at key 440
# Error at key 396
# Error at key 432
# Error at key 760
# Error at key 364
# Error at key 509
# Error at key 812
# Error at key 762
# Error at key 828
# Error at key 710
# Error at key 607
# Error at key 165
# Error at key 753
# Error at key 836
# Error at key 193
# Error at key 834
# Error at key 399
# Error at key 915
# Error at key 974
# Error at key 783
# Error at key 445
# Error at key 675
# Error at key 789
# Error at key 63
# Error at key 349
# Error at key 536
# Error at key 805
# Error at key 146
# Error at key 658
# Error at key 42
# Error at key 578
# Error at key 731
# Error at key 371
# Error at key 192
# Error at key 588
# Error at key 882
# Error at key 501
# Error at key 553
# Error at key 438
# Error at key 793
# Error at key 388
# Error at key 21
# Error at key 617
# Error at key 333
# Error at key 609
# Error at key 573
# Error at key 83
# Error at key 894
# Error at key 535
# Error at key 87
# Error at key 977
# Error at key 601
# Error at key 659
# Error at key 822
# Error at key 722
# Error at key 620
# Error at key 92
# Error at key 956
# Error at key 887
# Error at key 408
# Error at key 346
# Error at key 794
# Error at key 16
# Error at key 926
# Error at key 162
# Error at key 675
# Error at key 795
# Error at key 6
# Error at key 820
# Error at key 218
# Error at key 41
# Error at key 738
# Error at key 948
# Error at key 623
# Error at key 293
# Error at key 8
# Error at key 994
# Error at key 709
# Error at key 262
# Error at key 825
# Error at key 394
# Error at key 532
# Error at key 513
# Error at key 910
# Error at key 932
# Error at key 796
# Error at key 160
# Error at key 670
# Error at key 88
# Error at key 947
# Error at key 580
# Error at key 148
# Error at key 914
# Error at key 689
# Error at key 723
# Error at key 954
# Error at key 639
# Error at key 769
# Error at key 958
# Error at key 935
# Error at key 852
# Error at key 373
# Error at key 410
# Error at key 138
# Error at key 782
# Error at key 135
# Error at key 80
# Error at key 330
# Error at key 846
# Error at key 523
# Error at key 896
# Error at key 29
# Error at key 461
# Error at key 46
# Error at key 430
# Error at key 371
# Error at key 192
# Error at key 250
# Error at key 823
# Error at key 780
# Error at key 401
# Error at key 907
# Error at key 589
# Error at key 2
# Error at key 555
# Error at key 41
# Error at key 282
# Error at key 867
# Error at key 355
# Error at key 787
# Error at key 216
# Error at key 60
# Error at key 44
# Error at key 667
# Error at key 664
# Error at key 357
# Error at key 634
# Error at key 596
# Error at key 783
# Error at key 800
# Error at key 206
# Error at key 859
# Error at key 836
# Error at key 779
# Error at key 186
# Error at key 977
# Error at key 239
# Error at key 586
# Error at key 468
# Error at key 973
# Error at key 691
# Error at key 278
# Error at key 847
# Error at key 962
# Error at key 370
# Error at key 116
# Error at key 598
# Error at key 333
# Error at key 887
# Error at key 153
# Error at key 462
# Error at key 291
# Error at key 431
# Error at key 770
# Error at key 724
# Error at key 391
# Error at key 304
# Error at key 405
# Error at key 27
# Error at key 282
# Error at key 943
# Error at key 273
# Error at key 339
# Error at key 609
# Error at key 397
# Error at key 304
# Error at key 797
# Error at key 307
# Error at key 506
# Error at key 686
# Error at key 19
# Error at key 419
# Error at key 762
# Error at key 795
# Error at key 857
# Error at key 804
# Error at key 444
# Error at key 224
# Error at key 853
# Error at key 492
# Error at key 883
# Error at key 383
# Error at key 32
# Error at key 636
# Error at key 303
# Error at key 7
# Error at key 20
# Error at key 177
# Error at key 553
# Error at key 985
# Error at key 183
# Error at key 863
# Error at key 1
# Error at key 275
# Error at key 482
# Error at key 0
# Error at key 381
# Error at key 97
# Error at key 539
# Error at key 172
# Error at key 81
# Error at key 806
# Error at key 201
# Error at key 99
# Error at key 587
# Error at key 886
# Error at key 594
# Error at key 73
# Error at key 122
# Error at key 798
# Error at key 208
# Error at key 803
# Error at key 826
# Error at key 923
# Error at key 624
# Error at key 547
# Error at key 322
# Error at key 972
# Error at key 692
# Error at key 92
# Error at key 483
# Error at key 522
# Error at key 19
# Error at key 985
# Error at key 649
# Error at key 560
# Error at key 411
# Error at key 235
# Error at key 212
# Error at key 342
# Error at key 172
# Error at key 42
# Error at key 756
# Error at key 488
# Error at key 43
# Error at key 562
# Error at key 332
# Error at key 348
# Error at key 744
# Error at key 161
# Error at key 911
# Error at key 736
# Error at key 121
# Error at key 154
# Error at key 618
# Error at key 292
# Error at key 221
# Error at key 935
# Error at key 813
# Error at key 544
# Error at key 400
# Error at key 868
# Error at key 124
# Error at key 354
# Error at key 927
# Error at key 153
# Error at key 420
# Error at key 942
# Error at key 917
# Error at key 439
# Error at key 896
# Error at key 877
# Error at key 538
# Error at key 585
# Error at key 546
# Error at key 856
# Error at key 555
# Error at key 7
# Error at key 874
# Error at key 967
# Error at key 913
# Error at key 601
# Error at key 728
# Error at key 531
# Error at key 778
# Error at key 170
# Error at key 542
# Error at key 939
# Error at key 656
# Error at key 947
# Error at key 553
# Error at key 270
# Error at key 987
# Error at key 539
# Error at key 192
# Error at key 904
# Error at key 10
# Error at key 253
# Error at key 193
# Error at key 897
# Error at key 999
# Error at key 369
# Error at key 224
# Error at key 500
# Error at key 17
# Error at key 940
# Error at key 965
# Error at key 956
# Error at key 411
# Error at key 808
# Error at key 865
# Error at key 190
# Error at key 247
# Error at key 769
# Error at key 862
# Error at key 504
# Error at key 845
# Error at key 58
# Error at key 77
# Error at key 209
# Error at key 710
# Error at key 730
# Error at key 765
# Error at key 921
# Error at key 202
# Error at key 940
# Error at key 89
# Error at key 669
# Error at key 466
# Error at key 868
# Error at key 514
# Error at key 821
# Error at key 7
# Error at key 403
# Error at key 186
# Error at key 334
# Error at key 478
# Error at key 822
# Error at key 623
# Error at key 406
# Error at key 283
# Error at key 371
# Error at key 254
# Error at key 204
# Error at key 161
# Error at key 501
# Error at key 313
# Error at key 741
# Error at key 485
# Error at key 388
# Error at key 121
# Error at key 321
# Error at key 507
# Error at key 842
# Error at key 219
# Error at key 937
# Error at key 277
# Error at key 173
# Error at key 120
# Error at key 734
# Error at key 966
# Error at key 747
# Error at key 957
# Error at key 912
# Error at key 136
# Error at key 831
# Error at key 178
# Error at key 539
# Error at key 115
# Error at key 975
# Error at key 743
# Error at key 714
# Error at key 464
# Error at key 593
# Error at key 659
# Error at key 157
# Error at key 27
# Error at key 818
# Error at key 940
# Error at key 429
# Error at key 60
# Error at key 767
# Error at key 499
# Error at key 675
# Error at key 24
# Error at key 669
# Error at key 239
# Error at key 687
# Error at key 943
# Error at key 20
# Error at key 205
# Error at key 921
# Error at key 632
# Error at key 21
# Error at key 479
# Error at key 280
# Error at key 987
# Error at key 892
# Error at key 253
# Error at key 963
# Error at key 441
# Error at key 90
# Error at key 147
# Error at key 849
# Error at key 622
# Error at key 249
# Error at key 679
# Error at key 701
# Error at key 464
# Error at key 438
# Error at key 748
# Error at key 333
# Error at key 973
# Error at key 196
# Error at key 919
# Error at key 904
# Error at key 736
# Error at key 141
# Error at key 300
# Error at key 155
# Error at key 588
# Error at key 522
# Error at key 614
# Error at key 224
# Error at key 709
# Error at key 395
# Error at key 137
# Error at key 630
# Error at key 771
# Error at key 841
# Error at key 838
# Error at key 327
# Error at key 40
# Error at key 267
# Error at key 568
# Error at key 271
# Error at key 752
# Error at key 521
# Error at key 186
# Error at key 596
# Error at key 676
# Error at key 834
# Error at key 445
# Error at key 726
# Error at key 633
# Error at key 684
# Error at key 368
# Error at key 427
# Error at key 558
# Error at key 822
# Error at key 68
# Error at key 762
# Error at key 491
# Error at key 254
# Error at key 203
# Error at key 12
# Error at key 258
# Error at key 46
# Error at key 556
# Error at key 215
# Error at key 633
# Error at key 491
# Error at key 321
# Error at key 657
# Error at key 927
# Error at key 778
# Error at key 216
# Error at key 664
# Error at key 352
# Error at key 257
# Error at key 488
# Error at key 906
# Error at key 1
# Error at key 775
# Error at key 627
# Error at key 32
# Error at key 332
# Error at key 393
# Error at key 641
# Error at key 691
# Error at key 325
# Error at key 199
# Error at key 213
# Error at key 997
# Error at key 310
# Error at key 371
# Error at key 719
# Error at key 87
# Error at key 851
# Error at key 898
# Error at key 465
# Error at key 136
# Error at key 364
# Error at key 21
# Error at key 579
# Error at key 935
# Error at key 193
# Error at key 633
# Error at key 29
# Error at key 895
# Error at key 248
# Error at key 172
# Error at key 775
# Error at key 992
# Error at key 38
# Error at key 634
# Error at key 8
# Error at key 723
# Error at key 976
# Error at key 624
# Error at key 945
# Error at key 444
# Error at key 521
# Error at key 0
# Error at key 669
# Error at key 495
# Error at key 267
# Error at key 411
# Error at key 63
# Error at key 812
# Error at key 92
# Error at key 1000
# Error at key 199
# Error at key 570
# Error at key 688
# Error at key 826
# Error at key 142
# Error at key 783
# Error at key 338
# Error at key 183
# Error at key 571
# Error at key 928
# Error at key 610
# Error at key 722
# Error at key 513
# Error at key 988
# Error at key 776
# Error at key 24
# Error at key 339
# Error at key 472
# Error at key 323
# Error at key 667
# Error at key 587
# Error at key 435
# Error at key 640
# Error at key 53
# Error at key 147
# Error at key 91
# Error at key 367
# Error at key 152
# Error at key 794
# Error at key 918
# Error at key 168
# Error at key 424
# Error at key 604
# Error at key 53
# Error at key 729
# Error at key 271
# Error at key 946
# Error at key 667
# Error at key 524
# Error at key 125
# Error at key 773
# Error at key 122
# Error at key 285
# Error at key 891
# Error at key 225
# Error at key 459
# Error at key 932
# Error at key 302
# Error at key 977
# Error at key 418
# Error at key 41
# Error at key 661
# Error at key 537
# Error at key 437
# Error at key 378
# Error at key 763
# Error at key 788
# Error at key 501
# Error at key 172
# Error at key 252
# Error at key 757
# Error at key 87
# Error at key 383
# Error at key 923
# Error at key 36
# Error at key 972
# Error at key 964
# Error at key 825
# Error at key 432
# Error at key 530
# Error at key 227
# Error at key 436
# Error at key 66
# Error at key 330
# Error at key 409
# Error at key 139
# Error at key 161
# Error at key 374
# Error at key 344
# Error at key 361
# Error at key 72
# Error at key 62
# Error at key 714
# Error at key 814
# Error at key 575
# Error at key 455
# Error at key 194
# Error at key 727
# Error at key 390
# Error at key 11
# Error at key 827
# Error at key 99
# Error at key 700
# Error at key 872
# Error at key 470
# Error at key 392
# Error at key 728
# Error at key 832
# Error at key 599
# Error at key 14
# Error at key 357
# Error at key 908
# Error at key 468
# Error at key 623
# Error at key 116
# Error at key 422
# Error at key 49
# Error at key 235
# Error at key 776
# Error at key 159
# Error at key 484
# Error at key 489
# Error at key 966
# Error at key 904
# Error at key 844
# Error at key 716
# Error at key 375
# Error at key 723
# Error at key 307
# Error at key 678
# Error at key 210
# Error at key 678
# Error at key 726
# Error at key 756
# Error at key 85
# Error at key 511
# Error at key 720
# Error at key 210
# Error at key 99
# Error at key 726
# Error at key 137
# Error at key 543
# Error at key 89
# Error at key 297
# Error at key 93
# Error at key 537
# Error at key 686
# Error at key 707
# Error at key 366
# Error at key 296
# Error at key 258
# Error at key 527
# Error at key 555
# Error at key 436
# Error at key 77
# Error at key 479
# Error at key 616
# Error at key 400
# Error at key 405
# Error at key 624
# Error at key 338
# Error at key 925
# Error at key 471
# Error at key 410
# Error at key 613
# Error at key 589
# Error at key 31
# Error at key 36
# Error at key 446
# Error at key 659
# Error at key 715
# Error at key 327
# Error at key 533
# Error at key 783
# Error at key 421
# Error at key 756
# Error at key 649
# Error at key 147
# Error at key 899
# Error at key 268
# Error at key 904
# Error at key 492
# Error at key 212
# Error at key 30
# Error at key 560
# Error at key 912
# Error at key 225
# Error at key 490
# Error at key 301
# Error at key 770
# Error at key 99
# Error at key 234
# Error at key 777
# Error at key 495
# Error at key 541
# Error at key 354
# Error at key 439
# Error at key 644
# Error at key 421
# Error at key 603
# Error at key 234
# Error at key 781
# Error at key 92
# Error at key 532
# Error at key 915
# Error at key 610
# Error at key 910
# Error at key 950
# Error at key 90
# Error at key 536
# Error at key 957
# Error at key 629
# Error at key 378
# Error at key 730
# Error at key 605
# Error at key 203
# Error at key 174
# Error at key 313
# Error at key 435
# Error at key 627
# Error at key 192
# Error at key 444
# Error at key 767
# Error at key 830
# Error at key 798
# Error at key 401
# Error at key 900
# Error at key 426
# Error at key 842
# Error at key 772
# Error at key 991
# Error at key 968
# Error at key 460
# Error at key 627
# Error at key 504
# Error at key 901
# Error at key 932
# Error at key 583
# Error at key 496
# Error at key 646
# Error at key 348
# Error at key 887
# Error at key 540
# Error at key 10
# Error at key 187
# Error at key 97
# Error at key 683
# Error at key 852
# Error at key 895
# Error at key 419
# Error at key 20
# Error at key 273
# Error at key 941
# Error at key 939
# Error at key 273
# Error at key 35
# Error at key 703
# Error at key 205
# Error at key 182
# Error at key 144
# Error at key 471
# Error at key 680
# Error at key 255
# Error at key 606
# Error at key 845
# Error at key 767
# Error at key 158
# Error at key 69
# Error at key 382
# Error at key 128
# Error at key 471
# Error at key 155
# Error at key 590
# Error at key 876
# Error at key 766
# Error at key 316
# Error at key 26
# Error at key 253
# Error at key 98
# Error at key 859
# Error at key 550
# Error at key 366
# Error at key 88
# Error at key 722
# Error at key 27
# Error at key 467
# Error at key 407
# Error at key 544
# Error at key 566
# Error at key 487
# Error at key 601
# Error at key 14
# Error at key 228
# Error at key 504
# Error at key 493
# Error at key 756
# Error at key 236
# Error at key 415
# Error at key 312
# Error at key 791
# Error at key 385
# Error at key 405
# Error at key 595
# Error at key 701
# Error at key 119
# Error at key 894
# Error at key 445
# Error at key 802
# Error at key 319
# Error at key 649
# Error at key 837
# Error at key 804
# Error at key 567
# Error at key 366
# Error at key 565
# Error at key 167
# Error at key 752
# Error at key 871
# Error at key 104
# Error at key 142
# Error at key 408
# Error at key 585
# Error at key 949
# Error at key 914
# Error at key 963
# Error at key 239
# Error at key 633
# Error at key 998
# Error at key 183
# Error at key 346
# Error at key 392
# Error at key 141
# Error at key 715
# Error at key 932
# Error at key 530
# Error at key 981
# Error at key 400
# Error at key 136
# Error at key 96
# Error at key 886
# Error at key 53
# Error at key 792
# Error at key 525
# Error at key 701
# Error at key 208
# Error at key 774
# Error at key 204
# Error at key 733
# Error at key 966
# Error at key 325
# Error at key 808
# Error at key 56
# Error at key 160
# Error at key 277
# Error at key 293
# Error at key 722
# Error at key 921
# Error at key 897
# Error at key 478
# Error at key 575
# Error at key 416
# Error at key 113
# Error at key 258
# Error at key 707
# Error at key 714
# Error at key 105
# Error at key 68
# Error at key 541
# Error at key 801
# Error at key 259
# Error at key 889
# Error at key 266
# Error at key 660
# Error at key 202
# Error at key 590
# Error at key 428
# Error at key 367
# Error at key 101
# Error at key 551
# Error at key 228
# Error at key 580
# Error at key 807
# Error at key 968
# Error at key 418
# Error at key 412
# Error at key 427
# Error at key 188
# Error at key 530
# Error at key 15
# Error at key 130
# Error at key 604
# Error at key 612
# Error at key 377
# Error at key 552
# Error at key 111
# Error at key 393
# Error at key 424
# Error at key 680
# Error at key 46
# Error at key 912
# Error at key 470
# Error at key 608
# Error at key 263
# Error at key 294
# Error at key 671
# Error at key 679
# Error at key 676
# Error at key 172
# Error at key 224
# Error at key 885
# Error at key 596
# Error at key 668
# Error at key 298
# Error at key 300
# Error at key 956
# Error at key 33
# Error at key 505
# Error at key 670
# Error at key 855
# Error at key 68
# Error at key 161
# Error at key 744
# Error at key 321
# Error at key 879
# Error at key 436
# Error at key 750
# Error at key 50
# Error at key 60
# Error at key 568
# Error at key 324
# Error at key 92
# Error at key 386
# Error at key 644
# Error at key 540
# Error at key 828
# Error at key 322
# Error at key 440
# Error at key 452
# Error at key 735
# Error at key 99
# Error at key 619
# Error at key 401
# Error at key 277
# Error at key 710
# Error at key 138
# Error at key 650
# Error at key 278
# Error at key 37
# Error at key 982
# Error at key 260
# Error at key 854
# Error at key 363
# Error at key 835
# Error at key 889
# Error at key 5
# Error at key 443
# Error at key 493
# Error at key 561
# Error at key 724
# Error at key 94
# Error at key 678
# Error at key 943
# Error at key 403
# Error at key 84
# Error at key 263
# Error at key 456
# Error at key 179
# Error at key 934
# Error at key 326
# Error at key 293
# Error at key 506
# Error at key 852
# Error at key 409
# Error at key 31
# Error at key 426
# Error at key 559
# Error at key 0
# Error at key 925
# Error at key 646
# Error at key 301
# Error at key 269
# Error at key 224
# Error at key 939
# Error at key 950
# Error at key 614
# Error at key 155
# Error at key 284
# Error at key 455
# Error at key 571
# Error at key 462
# Error at key 823
# Error at key 299
# Error at key 285
# Error at key 997
# Error at key 290
# Error at key 565
# Error at key 792
# Error at key 603
# Error at key 134
# Error at key 90
# Error at key 99
# Error at key 60
# Error at key 284
# Error at key 404
# Error at key 833
# Error at key 154
# Error at key 942
# Error at key 469
# Error at key 628
# Error at key 542
# Error at key 840
# Error at key 725
# Error at key 781
# Error at key 973
# Error at key 829
# Error at key 138
# Error at key 830
# Error at key 190
# Error at key 940
# Error at key 282
# Error at key 632
# Error at key 929
# Error at key 802
# Error at key 46
# Error at key 444
# Error at key 553
# Error at key 332
# Error at key 906
# Error at key 335
# Error at key 29
# Error at key 211
# Error at key 936
# Error at key 410
# Error at key 199
# Error at key 960
# Error at key 804
# Error at key 95
# Error at key 508
# Error at key 57
# Error at key 643
# Error at key 649
# Error at key 933
# Error at key 227
# Error at key 152
# Error at key 155
# Error at key 280
# Error at key 521
# Error at key 814
# Error at key 552
# Error at key 374
# Error at key 820
# Error at key 15
# Error at key 668
# Error at key 965
# Error at key 273
# Error at key 307
# Error at key 704
# Error at key 952
# Error at key 83
# Error at key 196
# Error at key 369
# Error at key 386
# Error at key 844
# Error at key 8
# Error at key 634
# Error at key 110
# Error at key 701
# Error at key 749
# Error at key 156
# Error at key 630
# Error at key 379
# Error at key 109
# Error at key 168
# Error at key 753
# Error at key 160
# Error at key 489
# Error at key 531
# Error at key 213
# Error at key 765
# Error at key 752
# Error at key 957
# Error at key 755
# Error at key 768
# Error at key 500
# Error at key 116
# Error at key 898
# Error at key 568
# Error at key 960
# Error at key 722
# Error at key 213
# Error at key 402
# Error at key 540
# Error at key 635
# Error at key 894
# Error at key 547
# Error at key 923
# Error at key 799
# Error at key 987
# Error at key 389
# Error at key 665
# Error at key 33
# Error at key 52
# Error at key 719
# Error at key 314
# Error at key 423
# Error at key 729
# Error at key 778
# Error at key 247
# Error at key 253
# Error at key 628
# Error at key 679
# Error at key 586
# Error at key 657
# Error at key 198
# Error at key 698
# Error at key 560
# Error at key 904
# Error at key 446
# Error at key 175
# Error at key 710
# Error at key 905
# Error at key 520
# Error at key 408
# Error at key 6
# Error at key 614
# Error at key 837
# Error at key 606
# Error at key 437
# Error at key 257
# Error at key 585
# Error at key 348
# Error at key 227
# Error at key 682
# Error at key 565
# Error at key 167
# Error at key 795
# Error at key 387
# Error at key 96
# Error at key 598
# Error at key 495
# Error at key 186
# Error at key 945
# Error at key 917
# Error at key 171
# Error at key 72
# Error at key 293
# Error at key 712
# Error at key 731
# Error at key 591
# Error at key 766
# Error at key 814
# Error at key 65
# Error at key 527
# Error at key 273
# Error at key 613
# Error at key 600
# Error at key 715
# Error at key 724
# Error at key 899
# Error at key 649
# Error at key 304
# Error at key 289
# Error at key 638
# Error at key 989
# Error at key 346
# Error at key 496
# Error at key 957
# Error at key 360
# Error at key 55
# Error at key 190
# Error at key 139
# Error at key 54
# Error at key 93
# Error at key 537
# Error at key 793
# Error at key 457
# Error at key 79
# Error at key 621
# Error at key 740
# Error at key 603
# Error at key 104
# Error at key 407
# Error at key 489
# Error at key 172
# Error at key 96
# Error at key 170
# Error at key 354
# Error at key 764
# Error at key 259
# Error at key 566
# Error at key 993
# Error at key 804
# Error at key 164
# Error at key 401
# Error at key 180
# Error at key 440
# Error at key 288
# Error at key 922
# Error at key 467
# Error at key 743
# Error at key 751
# Error at key 431
# Error at key 917
# Error at key 864
# Error at key 771
# Error at key 407
# Error at key 116
# Error at key 971
# Error at key 703
# Error at key 485
# Error at key 862
# Error at key 848
# Error at key 212
# Error at key 312
# Error at key 64
# Error at key 62
# Error at key 942
# Error at key 232
# Error at key 817
# Error at key 416
# Error at key 529
# Error at key 189
# Error at key 732
# Error at key 291
# Error at key 549
# Error at key 583
# Error at key 598
# Error at key 252
# Error at key 333
# Error at key 358
# Error at key 466
# Error at key 721
# Error at key 491
# Error at key 706
# Error at key 814
# Error at key 884
# Error at key 861
# Error at key 365
# Error at key 906
# Error at key 809
# Error at key 629
# Error at key 524
# Error at key 1
# Error at key 901
# Error at key 427
# Error at key 646
# Error at key 439
# Error at key 143
# Error at key 969
# Error at key 997
# Error at key 762
# Error at key 695
# Error at key 630
# Error at key 238
# Error at key 934
# Error at key 111
# Error at key 135
# Error at key 68
# Error at key 287
# Error at key 590
# Error at key 853
# Error at key 726
# Error at key 234
# Error at key 260
# Error at key 413
# Error at key 208
# Error at key 439
# Error at key 98
# Error at key 133
# Error at key 80
# Error at key 575
# Error at key 902
# Error at key 920
# Error at key 629
# Error at key 933
# Error at key 743
# Error at key 217
# Error at key 136
# Error at key 543
# Error at key 744
# Error at key 634
# Error at key 481
# Error at key 966
# Error at key 218
# Error at key 379
# Error at key 502
# Error at key 245
# Error at key 924
# Error at key 957
# Error at key 68
# Error at key 548
# Error at key 738
# Error at key 931
# Error at key 603
# Error at key 399
# Error at key 389
# Error at key 315
# Error at key 27
# Error at key 131
# Error at key 606
# Error at key 405
# Error at key 719
# Error at key 827
# Error at key 587
# Error at key 180
# Error at key 416
# Error at key 420
# Error at key 410
# Error at key 641
# Error at key 748
# Error at key 374
# Error at key 361
# Error at key 535
# Error at key 394
# Error at key 115
# Error at key 158
# Error at key 148
# Error at key 217
# Error at key 552
# Error at key 343
# Error at key 174
# Error at key 115
# Error at key 417
# Error at key 676
# Error at key 898
# Error at key 693
# Error at key 296
# Error at key 401
# Error at key 800
# Error at key 160
# Error at key 563
# Error at key 378
# Error at key 269
# Error at key 35
# Error at key 852
# Error at key 77
# Error at key 444
# Error at key 860
# Error at key 217
# Error at key 885
# Error at key 119
# Error at key 758
# Error at key 5
# Error at key 633
# Error at key 588
# Error at key 162
# Error at key 459
# Error at key 848
# Error at key 623
# Error at key 587
# Error at key 305
# Error at key 72
# Error at key 658
# Error at key 260
# Error at key 948
# Error at key 944
# Error at key 906
# Error at key 728
# Error at key 210
# Error at key 106
# Error at key 573
# Error at key 637
# Error at key 159
# Error at key 191
# Error at key 87
# Error at key 694
# Error at key 919
# Error at key 848
# Error at key 80
# Error at key 374
# Error at key 3
# Error at key 25
# Error at key 365
# Error at key 512
# Error at key 618
# Error at key 276
# Error at key 522
# Error at key 914
# Error at key 776
# Error at key 214
# Error at key 198
# Error at key 556
# Error at key 446
# Error at key 792
# Error at key 588
# Error at key 721
# Error at key 167
# Error at key 77
# Error at key 131
# Error at key 858
# Error at key 323
# Error at key 779
# Error at key 530
# Error at key 500
# Error at key 222
# Error at key 511
# Error at key 445
# Error at key 810
# Error at key 484
# Error at key 364
# Error at key 532
# Error at key 199
# Error at key 132
# Error at key 891
# Error at key 153
# Error at key 566
# Error at key 99
# Error at key 108
# Error at key 823
# Error at key 798
# Error at key 910
# Error at key 271
# Error at key 831
# Error at key 182
# Error at key 769
# Error at key 70
# Error at key 734
# Error at key 152
# Error at key 635
# Error at key 23
# Error at key 485
# Error at key 179
# Error at key 472
# Error at key 257
# Error at key 528
# Error at key 724
# Error at key 592
# Error at key 4
# Error at key 640
# Error at key 956
# Error at key 189
# Error at key 649
# Error at key 871
# Error at key 583
# Error at key 571
# Error at key 337
# Error at key 361
# Error at key 913
# Error at key 135
# Error at key 741
# Error at key 886
# Error at key 760
# Error at key 447
# Error at key 104
# Error at key 839
# Error at key 672
# Error at key 973
# Error at key 760
# Error at key 45
# Error at key 730
# Error at key 231
# Error at key 713
# Error at key 734
# Error at key 28
# Error at key 788
# Error at key 343
# Error at key 41
# Error at key 193
# Error at key 263
# Error at key 302
# Error at key 533
# Error at key 915
# Error at key 212
# Error at key 536
# Error at key 281
# Error at key 119
# Error at key 776
# Error at key 193
# Error at key 12
# Error at key 511
# Error at key 151
# Error at key 57
# Error at key 589
# Error at key 356
# Error at key 192
# Error at key 354
# Error at key 122
# Error at key 391
# Error at key 203
# Error at key 913
# Error at key 847
# Error at key 167
# Error at key 760
# Error at key 130
# Error at key 532
# Error at key 973
# Error at key 927
# Error at key 297
# Error at key 419
# Error at key 117
# Error at key 982
# Error at key 13
# Error at key 465
# Error at key 298
# Error at key 55
# Error at key 802
# Error at key 829
# Error at key 977
# Error at key 556
# Error at key 904
# Error at key 17
# Error at key 84
# Error at key 132
# Error at key 757
# Error at key 839
# Error at key 385
# Error at key 116
# Error at key 288
# Error at key 181
# Error at key 791
# Error at key 757
# Error at key 489
# Error at key 811
# Error at key 587
# Error at key 386
# Error at key 379
# Error at key 948
# Error at key 775
# Error at key 305
# Error at key 585
# Error at key 505
# Error at key 832
# Error at key 146
# Error at key 630
# Error at key 851
# Error at key 601
# Error at key 525
# Error at key 206
# Error at key 788
# Error at key 287
# Error at key 947
# Error at key 26
# Error at key 838
# Error at key 611
# Error at key 350
# Error at key 934
# Error at key 765
# Error at key 561
# Error at key 557
# Error at key 201
# ...
# Error at key 883
# Error at key 378
# Error at key 621
# Error at key 306
# Error at key 50
# Error at key 159
# Error at key 939
# Error at key 155
# Error at key 230
# Error at key 309
# Error at key 551
# Error at key 261
# Error at key 158
# Error at key 648
# Error at key 29
# Error at key 361
# Error at key 118
# Error at key 634
# Error at key 675
# Error at key 106
# Error at key 213
# Error at key 524
# Error at key 973
# Error at key 135
# Error at key 557
# Error at key 984
# Error at key 494
# Error at key 474
# Error at key 825
# Error at key 929
# Error at key 202
# Error at key 178
# Error at key 484
# Error at key 452
# Error at key 67
# Error at key 612
# Error at key 766
# Error at key 881
# Error at key 440
# Error at key 942
# Error at key 496
# Error at key 94
# Error at key 901
# Error at key 896
# Error at key 372
# Error at key 759
# Error at key 451
# Error at key 809
# Error at key 43
# Error at key 370
# Error at key 978
# Error at key 514
# Error at key 557
# Error at key 595
# Error at key 835
# Error at key 481
# Error at key 366
# Error at key 357
# Error at key 847
# Error at key 666
# Error at key 546
# Error at key 51
# Error at key 607
# Error at key 756
# Error at key 171
# Error at key 774
# Error at key 365
# Error at key 159
# Error at key 709
# Error at key 308
# Error at key 459
# Error at key 943
# Error at key 594
# Error at key 913
# Error at key 760
# Error at key 286
# Error at key 618
# Error at key 675
# Error at key 488
# Error at key 801
# Error at key 545
# Error at key 275
# Error at key 904
# Error at key 724
# Error at key 740
# Error at key 927
# Error at key 792
# Error at key 93
# Error at key 444
# Error at key 35
# Error at key 38
# Error at key 883
# Error at key 344
# Error at key 14
# Error at key 912
# Error at key 77
# Error at key 577
# Error at key 986
# Error at key 601
# Error at key 772
# Error at key 617
# Error at key 973
# Error at key 989
# Error at key 110
# Error at key 706
# Error at key 225
# Error at key 861
# Error at key 200
# Error at key 600
# Error at key 230
# Error at key 70
# Error at key 351
# Error at key 301
# Error at key 568
# Error at key 751
# Error at key 359
# Error at key 329
# Error at key 547
# Error at key 969
# Error at key 796
# Error at key 290
# Error at key 288
# Error at key 755
# Error at key 397
# Error at key 312
# Error at key 766
# Error at key 449
# Error at key 727
# Error at key 426
# Error at key 2
# Error at key 422
# Error at key 125
# Error at key 88
# Error at key 111
# Error at key 179
# Error at key 60
# Error at key 178
# Error at key 524
# Error at key 319
# Error at key 721
# Error at key 82
# Error at key 11
# Error at key 737
# Error at key 279
# Error at key 817
# Error at key 454
# Error at key 843
# Error at key 657
# Error at key 398
# Error at key 982
# Error at key 796
# Error at key 188
# Error at key 652
# Error at key 243
# Error at key 259
# Error at key 545
# Error at key 935
# Error at key 644
# Error at key 28
# Error at key 776
# Error at key 827
# Error at key 192
# Error at key 283
# Error at key 604
# Error at key 575
# Error at key 980
# Error at key 501
# Error at key 272
# Error at key 902
# Error at key 386
# Error at key 610
# Error at key 535
# Error at key 350
# Error at key 274
# Error at key 919
# Error at key 948
# Error at key 549
# Error at key 1000
# Error at key 950
# Error at key 940
# Error at key 359
# Error at key 230
# Error at key 484
# Error at key 516
# Error at key 146
# Error at key 57
# Error at key 417
# Error at key 75
# Error at key 401
# Error at key 938
# Error at key 763
# Error at key 305
# Error at key 10
# Error at key 84
# Error at key 506
# Error at key 739
# Error at key 884
# Error at key 736
# Error at key 840
# Error at key 804
# Error at key 476
# Error at key 937
# Error at key 323
# Error at key 677
# Error at key 924
# Error at key 211
# Error at key 640
# Error at key 803
# Error at key 79
# Error at key 200
# Error at key 378
# Error at key 628
# Error at key 698
# Error at key 256
# Error at key 991
# Error at key 470
# Error at key 924
# Error at key 7
# Error at key 368
# Error at key 781
# Error at key 174
# Error at key 322
# Error at key 591
# Error at key 955
# Error at key 747
# Error at key 98
# Error at key 126
# Error at key 247
# Error at key 666
# Error at key 931
# Error at key 785
# Error at key 301
# Error at key 908
# Error at key 598
# Error at key 261
# Error at key 902
# Error at key 57
# Error at key 134
# Error at key 174
# Error at key 29
# Error at key 665
# Error at key 590
# Error at key 963
# Error at key 592
# Error at key 101
# Error at key 769
# Error at key 873
# Error at key 673
# Error at key 606
# Error at key 955
# Error at key 869
# Error at key 326
# Error at key 114
# Error at key 352
# Error at key 110
# Error at key 216
# Error at key 491
# Error at key 197
# Error at key 280
# Error at key 71
# Error at key 404
# Error at key 659
# Error at key 682
# Error at key 876
# Error at key 578
# Error at key 665
# Error at key 383
# Error at key 568
# Error at key 970
# Error at key 125
# Error at key 929
# Error at key 75
# Error at key 433
# Error at key 169
# Error at key 921
# Error at key 805
# Error at key 66
# Error at key 766
# Error at key 232
# Error at key 478
# Error at key 849
# Error at key 913
# Error at key 356
# Error at key 133
# Error at key 655
# Error at key 53
# Error at key 80
# Error at key 918
# Error at key 339
# Error at key 127
# Error at key 124
# Error at key 656
# Error at key 226
# Error at key 941
# Error at key 364
# Error at key 813
# Error at key 112
# Error at key 228
# Error at key 862
# Error at key 11
# Error at key 757
# Error at key 874
# Error at key 785
# Error at key 833
# Error at key 953
# Error at key 615
# Error at key 318
# Error at key 71
# Error at key 134
# Error at key 586
# Error at key 385
# Error at key 907
# Error at key 875
# Error at key 376
# Error at key 197
# Error at key 198
# Error at key 545
# Error at key 927
# Error at key 278
# Error at key 458
# Error at key 336
# Error at key 525
# Error at key 471
# Error at key 877
# Error at key 129
# Error at key 614
# Error at key 111
# Error at key 334
# Error at key 131
# Error at key 529
# Error at key 757
# Error at key 848
# Error at key 474
# Error at key 973
# Error at key 735
# Error at key 422
# Error at key 482
# Error at key 720
# Error at key 706
# Error at key 998
# Error at key 442
# Error at key 669
# Error at key 502
# Error at key 962
# Error at key 248
# Error at key 544
# Error at key 119
# Error at key 298
# Error at key 698
# Error at key 609
# Error at key 359
# Error at key 660
# Error at key 324
# Error at key 112
# Error at key 703
# Error at key 423
# Error at key 184
# Error at key 895
# Error at key 234
# Error at key 788
# Error at key 486
# Error at key 882
# Error at key 13
# Error at key 787
# Error at key 877
# Error at key 918
# Error at key 845
# Error at key 701
# Error at key 510
# Error at key 95
# Error at key 2
# Error at key 850
# Error at key 63
# Error at key 346
# Error at key 119
# Error at key 599
# Error at key 728
# Error at key 547
# Error at key 324
# Error at key 631
# Error at key 615
# Error at key 164
# Error at key 994
# Error at key 174
# Error at key 852
# Error at key 993
# Error at key 792
# Error at key 751
# Error at key 334
# Error at key 639
# Error at key 403
# Error at key 319
# Error at key 856
# Error at key 39
# Error at key 712
# Error at key 396
# Error at key 241
# Error at key 516
# Error at key 138
# Error at key 536
# Error at key 233
# Error at key 259
# Error at key 838
# Error at key 635
# Error at key 16
# Error at key 934
# Error at key 375
# Error at key 699
# Error at key 968
# Error at key 931
# Error at key 841
# Error at key 978
# Error at key 713
# Error at key 776
# Error at key 159
# Error at key 100
# Error at key 688
# Error at key 562
# Error at key 620
# Error at key 207
# Error at key 537
# Error at key 300
# Error at key 142
# Error at key 187
# Error at key 776
# Error at key 182
# Error at key 10
# Error at key 824
# Error at key 592
# Error at key 927
# Error at key 693
# Error at key 283
# Error at key 740
# Error at key 524
# Error at key 419
# Error at key 466
# Error at key 871
# Error at key 188
# Error at key 648
# Error at key 396
# Error at key 558
# Error at key 891
# Error at key 144
# Error at key 602
# Error at key 181
# Error at key 465
# Error at key 706
# Error at key 613
# Error at key 219
# Error at key 584
# Error at key 376
# Error at key 536
# Error at key 98
# Error at key 12
# Error at key 83
# Error at key 704
# Error at key 901
# Error at key 240
# Error at key 992
# Error at key 858
# Error at key 915
# Error at key 820
# Error at key 523
# Error at key 239
# Error at key 217
# Error at key 531
# Error at key 102
# Error at key 342
# Error at key 896
# Error at key 39
# Error at key 525
# Error at key 515
# Error at key 813
# Error at key 401
# Error at key 207
# Error at key 947
# Error at key 204
# Error at key 284
# Error at key 648
# Error at key 299
# Error at key 594
# Error at key 391
# Error at key 983
# Error at key 948
# Error at key 827
# Error at key 345
# Error at key 781
# Error at key 364
# Error at key 682
# Error at key 821
# Error at key 552
# Error at key 314
# Error at key 117
# Error at key 760
# Error at key 720
# Error at key 180
# Error at key 551
# Error at key 387
# Error at key 832
# Error at key 915
# Error at key 154
# Error at key 977
# Error at key 997
# Error at key 63
# Error at key 793
# Error at key 447
# Error at key 773
# Error at key 790
# Error at key 51
# Error at key 328
# Error at key 62
# Error at key 401
# Error at key 641
# Error at key 31
# Error at key 605
# Error at key 564
# Error at key 884
# Error at key 859
# Error at key 978
# Error at key 808
# Error at key 929
# Error at key 451
# Error at key 373
# Error at key 483
# Error at key 309
# Error at key 630
# Error at key 844
# Error at key 158
# Error at key 828
# Error at key 35
# Error at key 850
# Error at key 500
# Error at key 358
# Error at key 923
# Error at key 803
# Error at key 27
# Error at key 100
# Error at key 19
# Error at key 280
# Error at key 313
# Error at key 818
# Error at key 250
# Error at key 519
# Error at key 923
# Error at key 575
# Error at key 808
# Error at key 746
# Error at key 17
# Error at key 732
# Error at key 188
# Error at key 274
# Error at key 277
# Error at key 170
# Error at key 829
# Error at key 209
# Error at key 869
# Error at key 48
# Error at key 300
# Error at key 29
# Error at key 60
# Error at key 590
# Error at key 60
# Error at key 985
# Error at key 546
# Error at key 986
# Error at key 751
# Error at key 902
# Error at key 946
# Error at key 961
# Error at key 504
# Error at key 673
# Error at key 990
# Error at key 699
# Error at key 214
# Error at key 572
# Error at key 722
# Error at key 685
# Error at key 332
# Error at key 495
# Error at key 520
# Error at key 938
# Error at key 312
# Error at key 70
# Error at key 812
# Error at key 967
# Error at key 862
# Error at key 547
# Error at key 288
# Error at key 522
# Error at key 864
# Error at key 589
# Error at key 467
# Error at key 287
# Error at key 323
# Error at key 138
# Error at key 78
# Error at key 7
# Error at key 538
# Error at key 586
# Error at key 349
# Error at key 191
# Error at key 163
# Error at key 121
# Error at key 454
# Error at key 353
# Error at key 661
# Error at key 790
# Error at key 466
# Error at key 282
# Error at key 411
# Error at key 204
# Error at key 446
# Error at key 195
# Error at key 91
# Error at key 864
# Error at key 476
# Error at key 636
# Error at key 263
# Error at key 945
# Error at key 35
# Error at key 890
# Error at key 923
# Error at key 822
# Error at key 582
# Error at key 400
# Error at key 282
# Error at key 156
# Error at key 139
# Error at key 80
# Error at key 585
# Error at key 949
# Error at key 466
# Error at key 324
# Error at key 497
# Error at key 767
# Error at key 403
# Error at key 86
# Error at key 259
# Error at key 573
# Error at key 772
# Error at key 215
# Error at key 906
# Error at key 988
# Error at key 374
# Error at key 603
# Error at key 615
# Error at key 787
# Error at key 435
# Error at key 21
# Error at key 722
# Error at key 116
# Error at key 386
# Error at key 687
# Error at key 77
# Error at key 938
# Error at key 218
# Error at key 199
# Error at key 646
# Error at key 421
# Error at key 760
# Error at key 615
# Error at key 101
# Error at key 746
# Error at key 435
# Error at key 383
# Error at key 566
# Error at key 62
# Error at key 176
# Error at key 37
# Error at key 474
# Error at key 307
# Error at key 685
# Error at key 901
# Error at key 98
# Error at key 777
# Error at key 901
# Error at key 801
# Error at key 640
# Error at key 671
# Error at key 160
# Error at key 221
# Error at key 278
# Error at key 623
# Error at key 89
# Error at key 624
# Error at key 228
# Error at key 492
# Error at key 645
# Error at key 61
# Error at key 497
# Error at key 909
# Error at key 31
# Error at key 973
# Error at key 951
# Error at key 650
# Error at key 738
# Error at key 793
# Error at key 733
# Error at key 334
# Error at key 974
# Error at key 536
# Error at key 462
# Error at key 581
# Error at key 458
# Error at key 935
# Error at key 211
# Error at key 359
# Error at key 967
# Error at key 648
# Error at key 436
# Error at key 154
# Error at key 790
# Error at key 7
# Error at key 101
# Error at key 685
# Error at key 123
# Error at key 544
# Error at key 951
# Error at key 883
# Error at key 689
# Error at key 369
# Error at key 518
# Error at key 795
# Error at key 73
# Error at key 974
# Error at key 955
# Error at key 953
# Error at key 959
# Error at key 55
# Error at key 48
# Error at key 711
# Error at key 456
# Error at key 618
# Error at key 525
# Error at key 625
# Error at key 817
# Error at key 495
# Error at key 74
# Error at key 627
# Error at key 177
# Error at key 794
# Error at key 139
# Error at key 853
# Error at key 199
# Error at key 836
# Error at key 19
# Error at key 299
# Error at key 959
# Error at key 593
# Error at key 807
# Error at key 566
# Error at key 556
# Error at key 33
# Error at key 756
# Error at key 546
# Error at key 312
# Error at key 979
# Error at key 884
# Error at key 357
# Error at key 49
# Error at key 479
# Error at key 829
# Error at key 967
# Error at key 436
# Error at key 914
# Error at key 455
# Error at key 557
# Error at key 799
# Error at key 69
# Error at key 387
# Error at key 95
# Error at key 856
# Error at key 30
# Error at key 700
# Error at key 453
# Error at key 43
# Error at key 802
# Error at key 336
# Error at key 39
# Error at key 349
# Error at key 870
# Error at key 600
# Error at key 111
# Error at key 582
# Error at key 491
# Error at key 399
# Error at key 575
# Error at key 187
# Error at key 805
# Error at key 221
# Error at key 289
# Error at key 567
# Error at key 237
# Error at key 345
# Error at key 314
# Error at key 906
# Error at key 758
# Error at key 758
# Error at key 619
# Error at key 578
# Error at key 745
# Error at key 952
# Error at key 878
# Error at key 832
# Error at key 92
# Error at key 189
# Error at key 493
# Error at key 77
# Error at key 47
# Error at key 376
# Error at key 271
# Error at key 844
# Error at key 959
# Error at key 158
# Error at key 991
# Error at key 524
# Error at key 114
# Error at key 828
# Error at key 142
# Error at key 258
# Error at key 910
# Error at key 78
# Error at key 797
# Error at key 531
# Error at key 945
# Error at key 563
# Error at key 347
# Error at key 761
# Error at key 514
# Error at key 833
# Error at key 314
# Error at key 342
# Error at key 36
# Error at key 415
# Error at key 139
# Error at key 659
# Error at key 589
# Error at key 84
# Error at key 0
# Error at key 917
# Error at key 799
# Error at key 628
# Error at key 332
# Error at key 923
# Error at key 614
# Error at key 606
# Error at key 248
# Error at key 539
# Error at key 474
# Error at key 387
# Error at key 278
# Error at key 11
# Error at key 663
# Error at key 940
# Error at key 727
# Error at key 188
# Error at key 631
# Error at key 138
# Error at key 709
# Error at key 945
# Error at key 119
# Error at key 917
# Error at key 958
# Error at key 367
# Error at key 70
# Error at key 504
# Error at key 17
# Error at key 185
# Error at key 327
# Error at key 838
# Error at key 370
# Error at key 954
# Error at key 149
# Error at key 985
# Error at key 647
# Error at key 890
# Error at key 106
# Error at key 84
# Error at key 118
# Error at key 807
# Error at key 30
# Error at key 447
# Error at key 816
# Error at key 395
# Error at key 194
# Error at key 270
# Error at key 507
# Error at key 18
# Error at key 713
# Error at key 911
# Error at key 550
# Error at key 660
# Error at key 221
# Error at key 359
# Error at key 914
# Error at key 368
# Error at key 136
# Error at key 846
# Error at key 542
# Error at key 541
# Error at key 564
# Error at key 640
# Error at key 419
# Error at key 994
# Error at key 424
# Error at key 868
# Error at key 993
# Error at key 712
# Error at key 744
# Error at key 664
# Error at key 993
# Error at key 262
# Error at key 85
# Error at key 800
# Error at key 513
# Error at key 78
# Error at key 619
# Error at key 284
# Error at key 977
# Error at key 629
# Error at key 277
# Error at key 185
# Error at key 740
# Error at key 308
# Error at key 584
# Error at key 357
# Error at key 95
# Error at key 224
# Error at key 798
# Error at key 856
# Error at key 242
# Error at key 823
# Error at key 80
# Error at key 533
# Error at key 210
# Error at key 656
# Separate Chaining: 3585246 bytes, 1.1408164501190186 seconds
# Open Addressing Linear: 197841 bytes, 0.7095208168029785 seconds
# Open Addressing Quadratic: 55416 bytes, 0.23434114456176758 seconds

# %%
separate_chaining[594]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 separate_chaining[594]
#
# Cell In[19], line 35, in ClosedAddressingHashTable.__getitem__(self, key)
#      34 def __getitem__(self, key):
# ---> 35     return self.get(key)
#
# Cell In[19], line 98, in ClosedAddressingHashTable.get(self, key)
#      95 node = ll.find_key(key)
#      97 if node is None:
# ---> 98     raise KeyError(f"{key} not found")
#      99 else:
#     100     return node.value
#
# KeyError: '594 not found'
